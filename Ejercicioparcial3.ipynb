# %% [markdown]
# <a href="https://colab.research.google.com/github/lavjachica/programacionpython-2024/blob/main/Ejercicioparcial3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = "/content/drive/My Drive/ejercicioprogramacion/datanueva.csv"

# %%
datos = pd.read_csv(ruta)
datos.head(5)
datos.describe()  ### resumen estadistico condensado
# Out:
#                 ID  IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  1000.000000  843.000000  1.000000e+03
# mean    500.500000     7.949300   77.971530  2.736929e+05
# std     288.819436     0.275491   12.376099  3.273727e+05
# min       1.000000     7.600000   28.000000  2.508800e+04
# 25%     250.750000     7.700000   70.000000  5.552625e+04
# 50%     500.500000     7.900000   79.000000  1.385485e+05
# 75%     750.250000     8.100000   87.000000  3.741612e+05
# max    1000.000000     9.300000  100.000000  2.343110e+06

# %%
datos = pd.read_csv(ruta)
datos.head()
# Out:
#                Series_Title  ID  \
# 0  The Shawshank Redemption   1
# 1             The Godfather   2
# 2           The Dark Knight   3
# 3    The Godfather: Part II   4
# 4              12 Angry Men   5
#
#                                          Poster_Link Released_Year  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
#
#   Certificate  Runtime                 Genre  IMDB_Rating  \
# 0           A  142 min                 Drama          9.3
# 1           A  175 min          Crime, Drama          9.2
# 2          UA  152 min  Action, Crime, Drama          9.0
# 3           A  202 min          Crime, Drama          9.0
# 4           U   96 min          Crime, Drama          9.0
#
# ...

# %%
print(f'Cantidad de filas y columnas del data set: {datos.shape}') ##dimension del dataset
# Out:
# Cantidad de filas y columnas del data set: (1000, 17)

# %%
datos.info() ###muestra la cantidad de filas, registro, muestra el tipo de estructura de dato de cada columna, por ej. int64 es un dato numerico
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   ID             1000 non-null   int64
#  2   Poster_Link    1000 non-null   object
#  3   Released_Year  1000 non-null   object
#  4   Certificate    899 non-null    object
#  5   Runtime        1000 non-null   object
#  6   Genre          1000 non-null   object
#  7   IMDB_Rating    1000 non-null   float64
#  8   Overview       1000 non-null   object
#  9   Meta_score     843 non-null    float64
#  10  Director       1000 non-null   object
#  11  Star1          1000 non-null   object
#  12  Star2          1000 non-null   object
#  13  Star3          1000 non-null   object
#  14  Star4          1000 non-null   object
#  15  No_of_Votes    1000 non-null   int64
#  16  Gross          831 non-null    object
# ...

# %%
datos.isnull() ### identifica valores nulos/vacios
# Out:
#      Series_Title     ID  Poster_Link  Released_Year  Certificate  Runtime  \
# 0           False  False        False          False        False    False
# 1           False  False        False          False        False    False
# 2           False  False        False          False        False    False
# 3           False  False        False          False        False    False
# 4           False  False        False          False        False    False
# ..            ...    ...          ...            ...          ...      ...
# 995         False  False        False          False        False    False
# 996         False  False        False          False        False    False
# 997         False  False        False          False        False    False
# 998         False  False        False          False         True    False
# 999         False  False        False          False         True    False
#
# ...

# %%
datos.isnull().any()   ### En los True existen valores vacios CONSULTA LAS COLUMNAS CON VACIOS
# Out:
# Series_Title     False
# ID               False
# Poster_Link      False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %%
filas_nulas = datos[datos.isnull().any(axis=1)]
filas_nulas
# Out:
#                Series_Title    ID  \
# 18                 Hamilton    19
# 20          Soorarai Pottru    21
# 30                  Seppuku    31
# 32    It's a Wonderful Life    33
# 46           Hotaru no haka    47
# ..                      ...   ...
# 993                  Blowup   994
# 995  Breakfast at Tiffany's   996
# 996                   Giant   997
# 998                Lifeboat   999
# 999            The 39 Steps  1000
#
#                                            Poster_Link Released_Year  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...          2020
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...          1962
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...          1946
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...          1988
# ..                                                 ...           ...
# ...

# %%
filas_sin_nulos = filas_nulas.dropna()
filas_sin_nulos
# Out:
# Empty DataFrame
# Columns: [Series_Title, ID, Poster_Link, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %% [markdown]
# # **FILAS NULAS 'META_SCORE'**

# %%
filas_nulas_Meta = datos[datos['Meta_score'].isnull()]
filas_nulas_Meta
# Out:
#                       Series_Title   ID  \
# 20                 Soorarai Pottru   21
# 54       Ayla: The Daughter of War   55
# 55                    Vikram Vedha   56
# 57                          Dangal   58
# 65                Taare Zameen Par   66
# ..                             ...  ...
# 872  The Day the Earth Stood Still  873
# 874                          Gilda  875
# 899                      El cuerpo  900
# 909                      Celda 211  910
# 913                      Die Welle  914
#
#                                            Poster_Link Released_Year  \
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 54   https://m.media-amazon.com/images/M/MV5BNWJhMD...          2017
# 55   https://m.media-amazon.com/images/M/MV5BY2FiMT...          2017
# 57   https://m.media-amazon.com/images/M/MV5BMTQ4Mz...          2016
# 65   https://m.media-amazon.com/images/M/MV5BMDhjZW...          2007
# ...

# %% [markdown]
# # **FILAS NULAS DE 'CERTIFICATE'**

# %%
filas_nulas_certificate = datos[datos['Certificate'].isnull()]
filas_nulas_certificate
# Out:
#                   Series_Title    ID  \
# 30                     Seppuku    31
# 54   Ayla: The Daughter of War    55
# 77           Tengoku to jigoku    78
# 92              Babam ve Oglum    93
# 121                      Ikiru   122
# ..                         ...   ...
# 920        The Secret of Kells   921
# 926           Dead Man's Shoes   927
# 944            Batoru rowaiaru   945
# 998                   Lifeboat   999
# 999               The 39 Steps  1000
#
#                                            Poster_Link Released_Year  \
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...          1962
# 54   https://m.media-amazon.com/images/M/MV5BNWJhMD...          2017
# 77   https://m.media-amazon.com/images/M/MV5BOTI4NT...          1963
# 92   https://m.media-amazon.com/images/M/MV5BNjAzMz...          2005
# 121  https://m.media-amazon.com/images/M/MV5BZmM0NG...          1952
# ..                                                 ...           ...
# ...

# %%
cant_filas_nulas_Meta = datos['Meta_score'].isnull().sum()
print(f"cantidad de filas nulas: {cant_filas_nulas_Meta}")
# Out:
# cantidad de filas nulas: 157

# %%
cant_filas_nulas_certificate = datos ['Certificate'].isnull().sum()
print(f"cantidad de filas nulas: {cant_filas_nulas_certificate}")
# Out:
# cantidad de filas nulas: 101

# %%
data_sin_nulos = datos.dropna(subset=['Certificate', 'Meta_score']) ## esto borra los nulos de cada columna
data_sin_nulos.info()  ### cuantos datos me quedaron
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 0 to 997
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   787 non-null    object
#  1   ID             787 non-null    int64
#  2   Poster_Link    787 non-null    object
#  3   Released_Year  787 non-null    object
#  4   Certificate    787 non-null    object
#  5   Runtime        787 non-null    object
#  6   Genre          787 non-null    object
#  7   IMDB_Rating    787 non-null    float64
#  8   Overview       787 non-null    object
#  9   Meta_score     787 non-null    float64
#  10  Director       787 non-null    object
#  11  Star1          787 non-null    object
#  12  Star2          787 non-null    object
#  13  Star3          787 non-null    object
#  14  Star4          787 non-null    object
#  15  No_of_Votes    787 non-null    int64
#  16  Gross          714 non-null    object
# ...

# %%
promedio = data_sin_nulos.groupby('Director')['Meta_score'].mean()
promedio.head(10)
# Out:
# Director
# Aaron Sorkin             77.000000
# Abdellatif Kechiche      89.000000
# Abhishek Kapoor          40.000000
# Adam McKay               81.000000
# Akira Kurosawa           92.666667
# Alan J. Pakula           84.000000
# Alan Parker              57.000000
# Alejandro Amenábar       74.000000
# Alejandro G. Iñárritu    79.000000
# Alejandro Jodorowsky     76.000000
# Name: Meta_score, dtype: float64

# %%
def filtro_war(genres):
  return 'War' in genres

# Se aplica el filtro utilizando apply
datosWar = data_sin_nulos[data_sin_nulos['Genre'].apply(filtro_war)]

# %%
nombresWar = datosWar[['Series_Title','IMDB_Rating','Meta_score']]
nombresWar.head(20) ## Head muestra los primeros 20 elementos
# Out:
#                      Series_Title  IMDB_Rating  Meta_score
# 24            Saving Private Ryan          8.6        91.0
# 46                 Hotaru no haka          8.5        94.0
# 50                     Casablanca          8.5       100.0
# 74                 Apocalypse Now          8.4        94.0
# 80                 Paths of Glory          8.4        90.0
# 84                           1917          8.3        78.0
# 90                      Incendies          8.3        80.0
# 93           Inglourious Basterds          8.3        69.0
# 104             Full Metal Jacket          8.3        76.0
# 150               Pan's Labyrinth          8.2        98.0
# 172                           Ran          8.2        96.0
# 182         Judgment at Nuremberg          8.2        60.0
# 192            To Be or Not to Be          8.2        86.0
# 236         Taegukgi hwinalrimyeo          8.1        64.0
# 268                       Platoon          8.1        92.0
# ...
