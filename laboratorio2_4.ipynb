# %% [markdown]
# <a href="https://colab.research.google.com/github/lavjachica/programacionpython-2024/blob/main/laboratorio2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# 2. Crear un gráfico de un vector aleatorio de 10 elementos utilizando un gráfico de líneas. (50 Pts)

# %% [markdown]
# A. Crear un array aleatorio de 10 elementos. Los valores deben ser enteros entre el
# intervalo -5 al 5.

# %%
vector = np.random.randint(-5,5,10)
vector
# Out:
# array([-4,  1,  2,  1, -5, -1,  3,  1,  1, -3])

# %% [markdown]
# B. Implementar un gráfico de líneas simples a partir del vector obtenido. El gráfico debe
# tener:
# ● Marcadores por cada punto
# ● Etiqueta para el gráfico
# ● Nombre del gráfico, y nombrar los ejes X e Y

# %%
import matplotlib.pyplot as plt
plt.plot(vector, marker="x", label="Vector")
plt.title("Grafico de vector")
plt.xlabel("Posicion")
plt.ylabel("Vectores")

plt.legend()
plt.show()
